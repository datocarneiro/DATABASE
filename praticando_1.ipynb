# %% [markdown]
# # ***Pratica***
# Vamos criar uma banco para uma loja chamada `loja_atelie`
#
# nela terão 04 tabelas
# * tabela cliente
# * tabela pedido
# * tabela produto
# * tabela categoria

# %% [markdown]
# ## ***Diagrama***
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Criação Bando de dados

# %%
CREATE DATABASE IF NOT EXISTS sloja_atelie;

# %% [markdown]
# Criação tabela categoria

# %%
CREATE TABLE IF NOT EXISTS categoria(
    id_categoria INT AUTO_INCREMENT PRIMARY KEY,
    nome VARCHAR(50) NOT NULL
);

# %% [markdown]
# Criação tabela produto

# %%
CREATE TABLE IF NOT EXISTS produto(
    sku INT NOT NULL AUTO_INCREMENT PRIMARY KEY, 
    nome VARCHAR(50) NOT NULL,
    valor DECIMAL(6,2),
    id_categoria INT NULL,
    FOREIGN KEY (id_categoria) REFERENCES categoria(id_categoria)
);

# %% [markdown]
# Criação tabela cliente

# %%
CREATE TABLE IF NOT EXISTS cliente(
    id_cliente INT NOT NULL AUTO_INCREMENT PRIMARY KEY,
    nome VARCHAR(50) NOT NULL
);

# %% [markdown]
# Criação tabela pedido

# %%
CREATE TABLE IF NOT EXISTS pedido(
    numero_pedido INT NOT NULL AUTO_INCREMENT PRIMARY KEY,
    id_cliente INT,
    sku_produto INT,
    quantidade INT,
    data DATETIME NOT NULL,
    FOREIGN KEY (sku_produto) REFERENCES produto(sku),
    FOREIGN KEY (id_cliente) REFERENCES cliente(id_cliente)
);

# %% [markdown]
# ## ***Inserindo dados nas tabelas***

# %% [markdown]
# Inserindo valores na tabela categoria

# %%
INSERT INTO categoria VALUES
    (0, 'Vestuário'),
    (0, 'Alimento'),
    (0, 'Eletrônico');

# %% [markdown]
# Inserindo valores na tabela produto

# %%
INSERT INTO produto VALUES
    (0, 'Blusa', 89.99, 1),
    (0, 'Calça', 89.99, 1),
    (0, 'Arroz', 89.99, 2),
    (0, 'Feijão', 9.99, 2);

# %% [markdown]
# Inserindo valores na tabela cliente

# %%
INSERT INTO cliente VALUES
    (0, 'Dato'),
    (0, 'José'),
    (0, 'Manoel'),
    (0, 'Maria');

# %% [markdown]
# Inserindo valores na tabela pedido

# %%
INSERT INTO pedido VALUES
    # numero_pedido | id_clente | sku_produto | quantidade| data
		(0,            2,         1000,           1,      20240824),
		(0,            3,         1004,           2,      20240824),
		(0,            4,         1005,           5,      20240824),
		(0,            1,         1005,           5,      20240824),
		(0,            2,         1003,           1,      20240824),
		(0,            3,         1005,           3,      20240824),
		(0,            4,         1004,           3,      20240824),
		(0,            1,         1002,           2,      20240824),
		(0,            2,         1002,           2,      20240824),
		(0,            3,         1000,           1,      20240824),
		(0,            4,         1000,           3,      20240824),
		(0,            1,         1003,           5,      20240824);

# %% [markdown]
# ## ***Exibindo pedidos***

# %%
SELECT * FROM pedido;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ***Exibindo pedido com Junção***

# %%
SELECT 
    pedido.numero_pedido,
    cliente.nome,
    produto.sku,
    produto.nome,
    categoria.nome,
    pedido.quantidade,
    pedido.data
    FROM cliente JOIN pedido
    ON pedido.id_cliente = cliente.id_cliente
    JOIN produto ON pedido.sku_produto = produto.sku
    JOIN categoria ON produto.id_categoria = categoria.id_categoria;

# %% [markdown]
# ![image.png](attachment:image.png)
